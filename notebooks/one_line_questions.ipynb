# %%
import pandas as pd
from tqdm import tqdm

# Import a model to verify the setup
from twfy_vector_explorer import notebook_setup as notebook_setup
from vector_explorer.models import ParagraphVector

pd.set_option("display.max_colwidth", None)

# %% [markdown]
# # One line questions
#
# Here we're looking for text that signals we're starting and giving the whole motion in one line (and the parser shouldn't advance for me).

# %%
alts = [
    "the Bill be now read a Second time.",
    "the Bill be now read the Third time.",
    "That the House sit in private.",
    "That the Bill be read the Third time.",
    "That the clause be read a Second time.",
    "Main Question again proposed.",
    "Motion made, That the Bill be read be now read a Second time.",
    "Main Question again proposed .",
    "Question again proposed",
    "Motion made, That the Bill be now read a Secondtime.",
    "Question put, That the Bill be read a Second time.",
    "Question put, That the clause be a Second time.",
    "That the Bill be now read a second time",
    "That the Bill will be now read a second time.",
    "That the Bill now be read a third time.",
    "That the Bill be now read a third time.",
    "That the Bill be now read a second time",
]

false_positives = []


def in_alts(x: str):
    lx = x.lower().replace("  ", " ")
    for alt in alts + false_positives:
        if alt.lower() in lx:
            return True
    return False


search_query = alts[0]

all_dfs = []

for a in tqdm(alts):
    df = (
        ParagraphVector.objects.all()
        .search_distance(a, threshold=0.2)
        .df()
        .assign(text=lambda df: df["text"].str.strip())
        .drop_duplicates(subset="text", keep="first")
        .drop(columns=["embedding", "id", "source_file"])[
            lambda df: ~df["text"].apply(in_alts)
        ]
    )
    all_dfs.append(df)

df = pd.concat(all_dfs).drop_duplicates(subset="text", keep="first")
df = df.sort_values("distance").reset_index(drop=True)


# no matches that are an exact match - want to find similar items
df.head(30)
# Out:
# 100%|██████████| 17/17 [00:43<00:00,  2.59s/it]
#                                                   speech_id  \
# 0      uk.org.publicwhip/debate/2010-01-13d.669.2#d.669.2/1
# 1      uk.org.publicwhip/debate/2010-01-06b.174.1#b.174.1/6
# 2      uk.org.publicwhip/debate/2012-12-05a.919.1#a.919.1/8
# 3       uk.org.publicwhip/debate/2018-07-09c.750.1#c750.1/9
# 4      uk.org.publicwhip/debate/2011-01-10b.121.5#b.121.5/5
# 5     uk.org.publicwhip/debate/2012-09-03a.123.3#a.123.3/11
# 6      uk.org.publicwhip/debate/2013-11-25a.125.6#a.125.6/6
# 7      uk.org.publicwhip/debate/2015-01-27a.796.1#a.796.1/8
# 8      uk.org.publicwhip/debate/2010-02-05a.571.1#a.571.1/7
# 9     uk.org.publicwhip/debate/2012-10-30a.177.1#a.177.1/10
# 10     uk.org.publicwhip/debate/2010-10-25a.132.1#a.132.1/1
# 11      uk.org.publicwhip/debate/2019-10-29b.219.6#b219.6/2
# 12       uk.org.publicwhip/debate/2019-09-03b.81.2#b81.2/16
# 13     uk.org.publicwhip/debate/2017-04-24c.913.0#c913.0/20
# 14   uk.org.publicwhip/debate/2019-04-03b.1120.3#b1120.3/18
# 15      uk.org.publicwhip/debate/2017-01-26a.537.0#a537.0/2
# 16     uk.org.publicwhip/debate/2014-10-17a.586.1#a.586.1/2
# 17     uk.org.publicwhip/debate/2011-11-01d.864.1#d.864.1/3
# 18     uk.org.publicwhip/debate/2018-01-29c.634.0#c634.0/11
# 19      uk.org.publicwhip/debate/2018-04-16b.154.1#b154.1/1
# 20      uk.org.publicwhip/debate/2019-07-09c.226.1#c226.1/3
# 21     uk.org.publicwhip/debate/2011-10-13b.457.2#b.457.2/2
# 22      uk.org.publicwhip/debate/2018-09-11b.682.2#b682.2/3
# 23     uk.org.publicwhip/debate/2011-03-31d.571.1#d.571.1/3
# 24     uk.org.publicwhip/debate/2014-05-14d.836.5#d.836.5/2
# 25     uk.org.publicwhip/debate/2011-09-07b.455.1#b.455.1/5
# 26     uk.org.publicwhip/debate/2011-06-13a.510.1#a.510.1/7
# 27     uk.org.publicwhip/debate/2011-09-08b.605.0#b.605.0/3
# 28  uk.org.publicwhip/debate/2016-02-03b.903.565#b903.565/3
# 29       uk.org.publicwhip/debate/2011-10-10a.88.3#a.88.3/2
#
#                                                                      text  \
# 0                       Motion made, That the Bill be read a Second time.
# 1                           2. When the Bill has been read a second time-
# 2                           2. When the Bill has been read a second time—
# 3                          (2) When the Bill has been read a second time:
# 4                                    Bill accordingly read a Second time.
# 5                                  Bill accordingly read a Second  time .
# 6                                    Bill accordingly read a Second Time.
# 7                                    Bill accordingly read a second time.
# 8                                   Bill accordingly read a Second  time.
# 9                          (3) When the Bill has been read a second time—
# 10                  Question put, That the clause be read a Second time:-
# 11                         (3) When the Bill has been read a second time:
# 12                         (4) When the Bill has been read a second time:
# 13                         (9) When the Bill has been read a second time—
# 14                         (5) When the Bill has been read a second time:
# 15                          “before the Bill has been read a second time”
# 16                        This Bill is being presented for a second time.
# 17                       Clause read a Second time and added to the Bill.
# 18                 New clause 1 read a Second time and added to the Bill.
# 19                                Bill to be read a Second time tomorrow.
# 20                New clause 1 read a Second time, and added to the Bill.
# 21                                        Bill to be read the Third time.
# 22                New clause 2 read a Second time, and added to the Bill.
# 23   New clause 2 accordingly  read a Second time, and added to the Bill.
# 24    New clause 2 accordingly read a Second time, and added to the Bill.
# 25  New clause 1 accordingly read a Second time, and added to the  Bill .
# 26  New clause 1 accordingly read a Second  time , and added to the Bill.
# 27    New clause 1 accordingly read a Second time, and added to the Bill.
# 28                                                     Main Question put.
# 29                                                   Main  Question put .
#
#    transcript_type chamber_type  distance
# 0          debates   uk_commons  0.051820
# 1          debates   uk_commons  0.053653
# 2          debates   uk_commons  0.055618
# 3          debates   uk_commons  0.059468
# 4          debates   uk_commons  0.060133
# 5          debates   uk_commons  0.060133
# 6          debates   uk_commons  0.060133
# 7          debates   uk_commons  0.060133
# 8          debates   uk_commons  0.060133
# 9          debates   uk_commons  0.067286
# 10         debates   uk_commons  0.067360
# 11         debates   uk_commons  0.068558
# 12         debates   uk_commons  0.069905
# 13         debates   uk_commons  0.070073
# 14         debates   uk_commons  0.070101
# 15         debates   uk_commons  0.073110
# 16         debates   uk_commons  0.079721
# 17         debates   uk_commons  0.080108
# 18         debates   uk_commons  0.081732
# 19         debates   uk_commons  0.085048
# 20         debates   uk_commons  0.088065
# 21         debates   uk_commons  0.090673
# 22         debates   uk_commons  0.091780
# 23         debates   uk_commons  0.095555
# 24         debates   uk_commons  0.095555
# 25         debates   uk_commons  0.096932
# 26         debates   uk_commons  0.096932
# 27         debates   uk_commons  0.096932
# 28         debates   uk_commons  0.099517
# 29         debates   uk_commons  0.099517
