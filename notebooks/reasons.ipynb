# %%
import pandas as pd
from tqdm import tqdm

# Import a model to verify the setup
from twfy_vector_explorer import notebook_setup as notebook_setup
from vector_explorer.models import ParagraphVector

pd.set_option("display.max_colwidth", None)

# %% [markdown]
# # Leave for bill

# %%
alts = [
    "beg to move an amendment",
]

false_positives = []


def in_alts(x: str):
    lx = x.lower().replace("  ", " ")
    for alt in alts + false_positives:
        if alt.lower() in lx:
            return True
    return False


search_query = alts[0]

all_dfs = []

for a in tqdm(alts):
    df = (
        ParagraphVector.objects.all()
        .search_distance(a, threshold=0.2)
        .df()
        .assign(text=lambda df: df["text"].str.strip())
        .drop_duplicates(subset="text", keep="first")
        .drop(columns=["embedding", "id", "source_file"])[
            lambda df: ~df["text"].apply(in_alts)
        ]
    )
    all_dfs.append(df)

df = pd.concat(all_dfs).drop_duplicates(subset="text", keep="first")
df = df.sort_values("distance").reset_index(drop=True)


# no matches that are an exact match - want to find similar items
df.head(30)
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.55s/it]
#                                                  speech_id  \
# 0     uk.org.publicwhip/debate/2010-02-10b.947.0#b.947.0/1
# 1       uk.org.publicwhip/debate/2015-03-09a.86.4#a.86.4/1
# 2     uk.org.publicwhip/debate/2010-09-09b.526.0#b.526.0/1
# 3     uk.org.publicwhip/debate/2013-05-15b.655.6#b.655.6/1
# 4      uk.org.publicwhip/debate/2016-10-12b.324.4#b324.4/1
# 5     uk.org.publicwhip/debate/2013-06-18c.796.2#c.796.2/1
# 6   uk.org.publicwhip/debate/2011-02-03a.1081.0#a.1081.0/1
# 7    uk.org.publicwhip/debate/2019-10-24c.1162.5#c1162.5/1
# 8      uk.org.publicwhip/debate/2019-03-28b.674.6#b674.6/1
# 9     uk.org.publicwhip/debate/2013-07-10c.469.3#c.469.3/1
# 10     uk.org.publicwhip/debate/2023-11-15b.674.5#b674.5/1
# 11     uk.org.publicwhip/debate/2016-05-26b.732.4#b732.4/1
# 12     uk.org.publicwhip/debate/2017-07-17e.636.2#e636.2/1
# 13     uk.org.publicwhip/debate/2023-01-31b.229.4#b229.4/1
# 14    uk.org.publicwhip/debate/2010-01-21b.487.3#b.487.3/1
# 15  uk.org.publicwhip/debate/2012-02-23a.1081.0#a.1081.0/1
# 16    uk.org.publicwhip/debate/2010-01-20c.378.0#c.378.0/1
# 17     uk.org.publicwhip/debate/2018-12-04e.669.5#e669.5/1
# 18    uk.org.publicwhip/debate/2010-01-20c.355.1#c.355.1/1
# 19    uk.org.publicwhip/debate/2011-03-22a.911.3#a.911.3/1
# 20    uk.org.publicwhip/debate/2012-06-18b.626.4#b.626.4/1
# 21  uk.org.publicwhip/debate/2012-03-27a.1373.2#a.1373.2/1
# 22    uk.org.publicwhip/debate/2011-12-15a.962.0#a.962.0/1
# 23  uk.org.publicwhip/debate/2013-10-31a.1171.4#a.1171.4/1
# 24    uk.org.publicwhip/debate/2010-07-12a.739.0#a.739.0/1
# 25     uk.org.publicwhip/debate/2018-02-28b.887.0#b887.0/1
# 26        uk.org.publicwhip/senedd/en/2023-11-21.18.543796
# 27  uk.org.publicwhip/debate/2010-04-07b.1102.1#b.1102.1/1
# 28     uk.org.publicwhip/debate/2017-03-15c.479.2#c479.2/1
# 29     uk.org.publicwhip/debate/2017-02-20b.792.2#b792.2/1
#
#                                                                           text  \
# 0                                     I beg to move amendment (a), at end add:
# 1                                      I beg to move amendment (a), at end add
# 2                                     I beg to move amendment (a), at end add-
# 3                                     I beg to move amendment (g), at end add:
# 4                                      I beg to move amendment (b), at end add
# 5                                       I beg to move amendment (a), leave out
# 6                                    I beg to move amendment (a), to leave out
# 7                                      I beg to move amendment (g), at end add
# 8                                  I beg to move amendment (a), at end, to add
# 9                                                   I beg to move amendment 1.
# 10             I beg to move amendment (r), at the end of the Question to add:
# 11             I beg to move amendment (e), at the end of the Question to add:
# 12                           I beg to move amendment (a), after ‘That’, insert
# 13      I beg to move amendment (a), to leave out from “House” to end and add:
# 14                                                  I beg to move amendment 2.
# 15                            I beg to move amendment (a), after ‘(1)’, insert
# 16                     I beg to move amendment 6, page 1, line 14, at end add-
# 17  I beg to move amendment (a), leave out from “House” to the end and insert:
# 18                     I beg to move amendment 4, page 1, line 14, at end add-
# 19                     I beg to move amendment 2, page 2, line 14, at end add-
# 20                       I beg to move amendment 2, page 2, line 8, at end add
# 21             I beg to move amendment (a), at the end of the Question to add,
# 22       I beg to move amendment (a), to leave out from “House” to end and add
# 23                                                 I beg to move amendment 27.
# 24                     I beg to move amendment 49, page 1, line 6, at end add-
# 25                        I beg to move amendment (a), after “others,”, insert
# 26                                        I would like to move that amendment.
# 27                  I beg to move amendment 1, page 6, line 42, at end insert:
# 28                          I beg to move amendment 1, page 2, line 2, insert—
# 29                    I beg to move amendment 4, page 2, line 6, at end insert
#
#    transcript_type  chamber_type  distance
# 0          debates    uk_commons  0.048845
# 1          debates    uk_commons  0.056003
# 2          debates    uk_commons  0.058765
# 3          debates    uk_commons  0.065343
# 4          debates    uk_commons  0.068031
# 5          debates    uk_commons  0.070779
# 6          debates    uk_commons  0.071948
# 7          debates    uk_commons  0.073772
# 8          debates    uk_commons  0.075588
# 9          debates    uk_commons  0.081165
# 10         debates    uk_commons  0.081828
# 11         debates    uk_commons  0.089101
# 12         debates    uk_commons  0.090154
# 13         debates    uk_commons  0.091826
# 14         debates    uk_commons  0.093427
# 15         debates    uk_commons  0.093637
# 16         debates    uk_commons  0.093710
# 17         debates    uk_commons  0.096472
# 18         debates    uk_commons  0.098206
# 19         debates    uk_commons  0.099501
# 20         debates    uk_commons  0.100029
# 21         debates    uk_commons  0.100216
# 22         debates    uk_commons  0.100233
# 23         debates    uk_commons  0.100451
# 24         debates    uk_commons  0.101173
# 25         debates    uk_commons  0.101935
# 26         debates  welsh_senedd  0.102243
# 27         debates    uk_commons  0.102838
# 28         debates    uk_commons  0.103797
# 29         debates    uk_commons  0.103939
