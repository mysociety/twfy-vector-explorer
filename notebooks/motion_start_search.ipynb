# %%
import pandas as pd

# Import a model to verify the setup
from twfy_vector_explorer import notebook_setup as notebook_setup
from vector_explorer.models import ParagraphVector

pd.set_option("display.max_colwidth", None)

# %% [markdown]
# # Motion start text
#
# Here we're looking for text that is used to signal the *start* of a motion.

# %%
alts = [
    "I beg to move",
    "I beg move to move",
    "I therefore beg to move,",
    "Motion made, and Question proposed",
    "Amendment proposed: at the end of the Question to add:",
    "Amendment proposed : at the end of the Question to add:",
    "Motion made, and Question put",
    "Question again proposed",
    "Motion made, and Question p roposed",
    "Amendment proposed: (h), at the end of the Question to add:",
    "Motion made, Question put forthwith (Standing Order No. 83A(7)",
    "Amendment proposed (31 January):",
    "Amendment proposed (7 September):",
    "Amendment proposed: (a),",
    "Motion made , and Question proposed",
    "Motion made and Question proposed,",
    "Motion made and question proposed,",
    "Amendment proposed to new clause 1: (a),",
    "With this we will consider the following motion:",
    "With this we shall discuss the following motion:",
    "With this we will also consider the following motion:",
    "With this it will be convenient to discuss amendment (a),",
    "Motion mad e, and Question p roposed ,",
    "Motion made and Question put forthwith",
    "Motion made , and Question put f orthwith",
    "With this we shall consider the following motion:",
]

false_positives = ["Amendment proposed:"]


def in_alts(x: str):
    lx = x.lower().replace("  ", " ")
    for alt in alts + false_positives:
        if alt.lower() in lx:
            return True
    return False


search_query = alts[0]

all_dfs = []

for a in alts:
    df = (
        ParagraphVector.objects.all()
        .search_distance(a, threshold=0.2)
        .df()
        .assign(text=lambda df: df["text"].str.strip())
        .drop_duplicates(subset="text", keep="first")
        .drop(columns=["embedding", "id", "source_file"])[
            lambda df: ~df["text"].apply(in_alts)
        ]
    )
    all_dfs.append(df)

df = pd.concat(all_dfs).drop_duplicates(subset="text", keep="first")
df = df.sort_values("distance").reset_index(drop=True)


# no matches that are an exact match - want to find similar items
df.head(30)
# Out:
#                                                  speech_id  \
# 0     uk.org.publicwhip/debate/2015-06-24a.975.3#a.975.3/1
# 1   uk.org.publicwhip/debate/2010-03-04a.1096.1#a.1096.1/4
# 2     uk.org.publicwhip/debate/2012-04-18a.473.8#a.473.8/1
# 3    uk.org.publicwhip/debate/2016-02-09c.1460.0#c1460.0/3
# 4      uk.org.publicwhip/debate/2017-02-21b.979.1#b979.1/1
# 5     uk.org.publicwhip/debate/2012-04-18a.473.2#a.473.2/1
# 6     uk.org.publicwhip/debate/2012-03-12a.102.1#a.102.1/2
# 7   uk.org.publicwhip/debate/2010-03-04a.1096.1#a.1096.1/6
# 8   uk.org.publicwhip/debate/2012-02-23a.1081.1#a.1081.1/2
# 9   uk.org.publicwhip/debate/2012-02-23a.1081.1#a.1081.1/4
# 10  uk.org.publicwhip/debate/2011-03-23b.1052.3#b.1052.3/1
# 11    uk.org.publicwhip/debate/2011-06-22b.443.8#b.443.8/1
# 12    uk.org.publicwhip/debate/2010-07-13c.920.5#c.920.5/1
# 13     uk.org.publicwhip/debate/2019-02-27a.453.1#a453.1/2
# 14    uk.org.publicwhip/debate/2012-06-14a.484.0#a.484.0/3
# 15   uk.org.publicwhip/debate/2013-12-10b.179.0#b.179.0/14
# 16    uk.org.publicwhip/debate/2014-11-26a.949.3#a.949.3/2
# 17  uk.org.publicwhip/debate/2013-07-17b.1141.1#b.1141.1/2
# 18     uk.org.publicwhip/debate/2018-03-07c.382.0#c382.0/1
# 19    uk.org.publicwhip/debate/2011-06-22c.407.1#c.407.1/2
# 20   uk.org.publicwhip/debate/2010-01-25b.633.3#b.633.3/26
# 21    uk.org.publicwhip/lords/2023-07-04a.1116.1#a1116.1/2
# 22     uk.org.publicwhip/debate/2015-09-07b.78.3#b.78.3/29
# 23     uk.org.publicwhip/debate/2017-01-10c.230.1#c230.1/2
# 24    uk.org.publicwhip/debate/2012-07-16d.741.3#d.741.3/7
# 25     uk.org.publicwhip/debate/2023-07-18c.860.2#c860.2/1
# 26   uk.org.publicwhip/debate/2016-06-08a.1288.1#a1288.1/5
# 27    uk.org.publicwhip/lords/2023-03-14a.1198.1#a1198.1/2
# 28   uk.org.publicwhip/debate/2010-02-09b.791.1#b.791.1/11
# 29    uk.org.publicwhip/lords/2023-06-08b.1607.5#b1607.5/2
#
#                                                                           text  \
# 0                                                       What about the motion?
# 1                                                    Amendment (a), at end add
# 2   Motion made , and Question put f orthwith (Standing Order No. 119 ( 11 )),
# 3                                                       The motion talks about
# 4                            With this we shall consider the following motion:
# 5        Motion made , and Question put forthwith (Standing Order No. 118(6)),
# 6                                             Amendment made: (a), at end, add
# 7                                                    Amendment (d), at end add
# 8                                                    Amendment (b), at end add
# 9                                                    Amendment (c), at end add
# 10                                                                Motion made,
# 11                                                              Motion  made ,
# 12                                                               Motion made ,
# 13                                            Amendment made: (b), at end, add
# 14                                                     as the motion suggests.
# 15                      Amendment proposed to new clause 3: (a) at end insert—
# 16                                                      The motion refers to a
# 17                                                    The motion refers to the
# 18                                                            The motion says:
# 19                                                        The motion refers to
# 20                        Question put, That the clause be added to the Bill:-
# 21                         At end insert “and do propose Amendment 2D in lieu—
# 22                                  Amendment (a) to new clause 6, at end add—
# 23                                                                    Clause 1
# 24                                                        The motion speaks of
# 25           With this it will be convenient to consider the following motion:
# 26                                                  The motion goes on to note
# 27     At end insert “and do propose the following amendments to Amendment 1A—
# 28                                               Amendment (l), at end insert-
# 29                         At end insert “and do propose Amendment 2B in lieu—
#
#    transcript_type chamber_type  distance
# 0          debates   uk_commons  0.104393
# 1          debates   uk_commons  0.114491
# 2          debates   uk_commons  0.116503
# 3          debates   uk_commons  0.117889
# 4          debates   uk_commons  0.124117
# 5          debates   uk_commons  0.124977
# 6          debates   uk_commons  0.126253
# 7          debates   uk_commons  0.129599
# 8          debates   uk_commons  0.133083
# 9          debates   uk_commons  0.136563
# 10         debates   uk_commons  0.139853
# 11         debates   uk_commons  0.139854
# 12         debates   uk_commons  0.139854
# 13         debates   uk_commons  0.144540
# 14         debates   uk_commons  0.144949
# 15         debates   uk_commons  0.145814
# 16         debates   uk_commons  0.150317
# 17         debates   uk_commons  0.152803
# 18         debates   uk_commons  0.154794
# 19         debates   uk_commons  0.155748
# 20         debates   uk_commons  0.156841
# 21         debates     uk_lords  0.157858
# 22         debates   uk_commons  0.158765
# 23         debates   uk_commons  0.159298
# 24         debates   uk_commons  0.159536
# 25         debates   uk_commons  0.159550
# 26         debates   uk_commons  0.159631
# 27         debates     uk_lords  0.160068
# 28         debates   uk_commons  0.160107
# 29         debates     uk_lords  0.160328
